# %%
object_name = {'process_name1':['object1','object2','object3'],
               'process_name2':['object1','object2']
              } # n number of objects

# %%
excluded_columns =['created_date__v','modified_date__v'] # n number of columns
